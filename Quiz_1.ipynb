# %% [markdown]
# <a href="https://colab.research.google.com/github/PacificG/mlcourse.ai/blob/master/Quiz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
X = load_iris()

# %%
Data = pd.DataFrame(data = np.c_[X['data'], X['target']],
                   columns = X['feature_names'] + ['target'])

# %%
Data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2     0.0
# 1                4.9               3.0  ...               0.2     0.0
# 2                4.7               3.2  ...               0.2     0.0
# 3                4.6               3.1  ...               0.2     0.0
# 4                5.0               3.6  ...               0.2     0.0
#
# [5 rows x 5 columns]

# %%
X, y = Data.drop('target' , axis=1), Data['target']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth = 4, random_state = 17)

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=17, splitter='best')

# %%
from sklearn.tree import export_graphviz

# %%
treedot = export_graphviz(clf, filled = True, )

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.6/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from pydotplus) (2.4.2)

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (0.10.1)

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(treedot)

# %%
from IPython.display import Image

# %%
Image(graph.create_png())
